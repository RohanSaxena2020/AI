# %% [markdown]
# Using heart disease dataset heart.csv, do following, (credits of dataset:  https://www.kaggle.com/fedesoriano/heart-failure-prediction)
#
# 1. Load heart disease dataset in pandas dataframe
# 1. Remove outliers using Z score. Usual guideline is to remove anything that has Z score > 3 formula or Z score < -3
# 1. Convert text columns to numbers using label encoding and one hot encoding
# 1. Apply scaling
# 1. Build a classification model using support vector machine. Use standalone model as well as Bagging model and check if you see any difference in the performance.
# 1. Now use decision tree classifier. Use standalone model as well as Bagging and check if you notice any difference in performance
# 1. Comparing performance of svm and decision tree classifier figure out where it makes most sense to use bagging and why. Use internet to figure out in what conditions bagging works the best.

# %%
import pandas as pd

df = pd.read_csv("heart.csv")

print(df.shape)
df.head()
# Out:
# (918, 12)
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
# Check for N/A values

df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# ### No N/A values

# %% [markdown]
# ### For each numeric column, find all outliers (Z score <-3 or >3)

# %%
df_numeric = df[["Age","RestingBP","Cholesterol","FastingBS","MaxHR","Oldpeak"]]

df_numeric.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak
# 0   40        140          289          0    172      0.0
# 1   49        160          180          0    156      1.0
# 2   37        130          283          0     98      0.0
# 3   48        138          214          0    108      1.5
# 4   54        150          195          0    122      0.0

# %%
# Now, add a z score column

for i in df_numeric.columns:
    df[i+'_z_score'] = df[i].apply(lambda x: (x - df[i].mean()) / df[i].std())

df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Age_z_score  \
# 0              N      0.0       Up             0    -1.432359
# 1              N      1.0     Flat             1    -0.478223
# 2              N      0.0       Up             0    -1.750404
# 3              Y      1.5     Flat             1    -0.584238
# 4              N      0.0       Up             0     0.051853
#
#    RestingBP_z_score  Cholesterol_z_score  FastingBS_z_score  MaxHR_z_score  \
# 0           0.410685             0.824621          -0.551041       1.382175
# 1           1.490940            -0.171867          -0.551041       0.753746
# 2          -0.129442             0.769768          -0.551041      -1.524307
# 3           0.302660             0.138964          -0.551041      -1.131539
# 4           0.950812            -0.034736          -0.551041      -0.581664
#
#    Oldpeak_z_score
# 0        -0.831979
# 1         0.105606
# 2        -0.831979
# 3         0.574398
# 4        -0.831979

# %%
# Sanity check

print(df["Age"].mean())
print(df["Age"].std())
# Out:
# 53.510893246187365
# 9.43261650673201

# %%
(40-df["Age"].mean())/df["Age"].std()
# Out:
# -1.4323590105189488

# %% [markdown]
# This matches our column

# %%
# Sanity check #2

print(df["MaxHR"].mean())
print(df["MaxHR"].std())
# Out:
# 136.80936819172112
# 25.4603341382503

# %%
(108-df["MaxHR"].mean())/df["MaxHR"].std()
# Out:
# -1.1315392812712306

# %% [markdown]
# This also matches

# %%
df_outliers = df[(df["Age_z_score"]< -3) | (df["Age_z_score"]> 3)]

print(df.shape)

df
# Out:
# (918, 18)
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Age_z_score  \
# 0      172              N      0.0       Up             0    -1.432359
# 1      156              N      1.0     Flat             1    -0.478223
# 2       98              N      0.0       Up             0    -1.750404
# 3      108              Y      1.5     Flat             1    -0.584238
# 4      122              N      0.0       Up             0     0.051853
# ..     ...            ...      ...      ...           ...          ...
# 913    132              N      1.2     Flat             1    -0.902283
# 914    141              N      3.4     Flat             1     1.536064
# 915    115              Y      1.2     Flat             1     0.369898
# 916    174              N      0.0     Flat             1     0.369898
# 917    173              N      0.0       Up             0    -1.644389
#
#      RestingBP_z_score  Cholesterol_z_score  FastingBS_z_score  MaxHR_z_score  \
# 0             0.410685             0.824621          -0.551041       1.382175
# 1             1.490940            -0.171867          -0.551041       0.753746
# 2            -0.129442             0.769768          -0.551041      -1.524307
# 3             0.302660             0.138964          -0.551041      -1.131539
# 4             0.950812            -0.034736          -0.551041      -0.581664
# ..                 ...                  ...                ...            ...
# 913          -1.209697             0.596068          -0.551041      -0.188897
# 914           0.626736            -0.053020           1.812770       0.164595
# 915          -0.129442            -0.619830          -0.551041      -0.856602
# 916          -0.129442             0.340090          -0.551041       1.460728
# 917           0.302660            -0.217578          -0.551041       1.421452
#
#      Oldpeak_z_score
# 0          -0.831979
# 1           0.105606
# 2          -0.831979
# 3           0.574398
# 4          -0.831979
# ..               ...
# 913         0.293123
# 914         2.355810
# 915         0.293123
# 916        -0.831979
# 917        -0.831979
#
# [918 rows x 18 columns]

# %%
df_outliers = df[(df["RestingBP_z_score"]< -3) | (df["RestingBP_z_score"]> 3)]

print(df_outliers.shape)

df_outliers
# Out:
# (8, 18)
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 109   39   M           ATA        190          241          0     Normal
# 241   54   M           ASY        200          198          0     Normal
# 365   64   F           ASY        200            0          0     Normal
# 399   61   M           NAP        200            0          1         ST
# 449   55   M           NAP          0            0          0     Normal
# 592   61   M           ASY        190          287          1        LVH
# 732   56   F           ASY        200          288          1        LVH
# 759   54   M           ATA        192          283          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Age_z_score  \
# 109    106              N      0.0       Up             0    -1.538374
# 241    142              Y      2.0     Flat             1     0.051853
# 365    140              Y      1.0     Flat             1     1.112004
# 399     70              N      0.0     Flat             1     0.793959
# 449    155              N      1.5     Flat             1     0.157868
# 592    150              Y      2.0     Down             1     0.793959
# 732    133              Y      4.0     Down             1     0.263883
# 759    195              N      0.0       Up             1     0.051853
#
#      RestingBP_z_score  Cholesterol_z_score  FastingBS_z_score  MaxHR_z_score  \
# 109           3.111322             0.385800          -0.551041      -1.210093
# 241           3.651449            -0.007310          -0.551041       0.203871
# 365           3.651449            -1.817444          -0.551041       0.125318
# 399           3.651449            -1.817444           1.812770      -2.624057
# 449          -7.151097            -1.817444          -0.551041       0.714469
# 592           3.111322             0.806337           1.812770       0.518086
# 732           3.651449             0.815479           1.812770      -0.149620
# 759           3.219347             0.769768          -0.551041       2.285541
#
#      Oldpeak_z_score
# 109        -0.831979
# 241         1.043191
# 365         0.105606
# 399        -0.831979
# 449         0.574398
# 592         1.043191
# 732         2.918360
# 759        -0.831979

# %%
df_outliers = df[(df["Cholesterol_z_score"]< -3) | (df["Cholesterol_z_score"]> 3)]

print(df_outliers.shape)

df_outliers
# Out:
# (3, 18)
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 76    32   M           ASY        118          529          0     Normal
# 149   54   M           ASY        130          603          1     Normal
# 616   67   F           NAP        115          564          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Age_z_score  \
# 76     130              N      0.0     Flat             1    -2.280480
# 149    125              Y      1.0     Flat             1     0.051853
# 616    160              N      1.6     Flat             0     1.430049
#
#      RestingBP_z_score  Cholesterol_z_score  FastingBS_z_score  MaxHR_z_score  \
# 76           -0.777595             3.018723          -0.551041      -0.267450
# 149          -0.129442             3.695238           1.812770      -0.463834
# 616          -0.939633             3.338696          -0.551041       0.910853
#
#      Oldpeak_z_score
# 76         -0.831979
# 149         0.105606
# 616         0.668157

# %%
df_outliers = df[(df["FastingBS_z_score"]< -3) | (df["FastingBS_z_score"]> 3)]

print(df_outliers.shape)

df_outliers
# Out:
# (0, 18)
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease, Age_z_score, RestingBP_z_score, Cholesterol_z_score, FastingBS_z_score, MaxHR_z_score, Oldpeak_z_score]
# Index: []

# %%
df_outliers = df[(df["MaxHR_z_score"]< -3) | (df["MaxHR_z_score"]> 3)]

print(df_outliers.shape)

df_outliers
# Out:
# (1, 18)
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 390   51   M           ASY        140            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Age_z_score  \
# 390     60              N      0.0     Flat             1    -0.266193
#
#      RestingBP_z_score  Cholesterol_z_score  FastingBS_z_score  MaxHR_z_score  \
# 390           0.410685            -1.817444          -0.551041      -3.016825
#
#      Oldpeak_z_score
# 390        -0.831979

# %%
df_outliers = df[(df["Oldpeak_z_score"]< -3) | (df["Oldpeak_z_score"]> 3)]

print(df_outliers.shape)

df_outliers
# Out:
# (7, 18)
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 166   50   M           ASY        140          231          0         ST
# 324   46   M           ASY        100            0          1         ST
# 702   59   M            TA        178          270          0        LVH
# 771   55   M           ASY        140          217          0     Normal
# 791   51   M           ASY        140          298          0     Normal
# 850   62   F           ASY        160          164          0        LVH
# 900   58   M           ASY        114          318          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Age_z_score  \
# 166    140              Y      5.0     Flat             1    -0.372208
# 324    133              N     -2.6     Flat             1    -0.796268
# 702    145              N      4.2     Down             0     0.581928
# 771    111              Y      5.6     Down             1     0.157868
# 791    122              Y      4.2     Flat             1    -0.266193
# 850    145              N      6.2     Down             1     0.899974
# 900    140              N      4.4     Down             1     0.475913
#
#      RestingBP_z_score  Cholesterol_z_score  FastingBS_z_score  MaxHR_z_score  \
# 166           0.410685             0.294379          -0.551041       0.125318
# 324          -1.749824            -1.817444           1.812770      -0.149620
# 702           2.463169             0.650921          -0.551041       0.321702
# 771           0.410685             0.166390          -0.551041      -1.013709
# 791           0.410685             0.906900          -0.551041      -0.581664
# 850           1.490940            -0.318141          -0.551041       0.321702
# 900          -0.993646             1.089741          -0.551041       0.125318
#
#      Oldpeak_z_score
# 166         3.855945
# 324        -3.269699
# 702         3.105877
# 771         4.418496
# 791         3.105877
# 850         4.981047
# 900         3.293394

# %% [markdown]
# We found all the outliers, time to remove

# %%
# shape to start

df.shape
# Out:
# (918, 18)

# %%
df_no_outliers = df

for column in df_no_outliers.columns:
    if column.endswith('_z_score'):
        df_no_outliers = df_no_outliers[(df_no_outliers[column]>= -3) & (df_no_outliers[column] <= 3)]

df_no_outliers.shape
# Out:
# (899, 18)

# %% [markdown]
# We removed all 19 outliers!!

# %%
df_no_outliers.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease  Age_z_score  \
# 0              N      0.0       Up             0    -1.432359
# 1              N      1.0     Flat             1    -0.478223
# 2              N      0.0       Up             0    -1.750404
# 3              Y      1.5     Flat             1    -0.584238
# 4              N      0.0       Up             0     0.051853
#
#    RestingBP_z_score  Cholesterol_z_score  FastingBS_z_score  MaxHR_z_score  \
# 0           0.410685             0.824621          -0.551041       1.382175
# 1           1.490940            -0.171867          -0.551041       0.753746
# 2          -0.129442             0.769768          -0.551041      -1.524307
# 3           0.302660             0.138964          -0.551041      -1.131539
# 4           0.950812            -0.034736          -0.551041      -0.581664
#
#    Oldpeak_z_score
# 0        -0.831979
# 1         0.105606
# 2        -0.831979
# 3         0.574398
# 4        -0.831979

# %%
# Drop the specified columns from df_no_outliers in place
df_no_outliers.drop(["Age_z_score","RestingBP_z_score","Cholesterol_z_score",
                     "FastingBS_z_score","MaxHR_z_score","Oldpeak_z_score"], axis=1, inplace=True)

# Display the first few rows of the updated DataFrame
df_no_outliers.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ##### Convert text columns to numbers using label encoding and one hot encoding

# %%
df_categorical = df_no_outliers[["Sex","ChestPainType","RestingECG","ExerciseAngina","ST_Slope"]]

for i in df_categorical.columns:
    print(df_categorical[i].unique())
# Out:
# ['M' 'F']
# ['ATA' 'NAP' 'ASY' 'TA']
# ['Normal' 'ST' 'LVH']
# ['N' 'Y']
# ['Up' 'Flat' 'Down']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df_no_outliers
dfle.Sex = le.fit_transform(dfle.Sex)
dfle.ChestPainType = le.fit_transform(dfle.ChestPainType)
dfle.RestingECG = le.fit_transform(dfle.RestingECG)
dfle.ExerciseAngina = le.fit_transform(dfle.ExerciseAngina)
dfle.ST_Slope = le.fit_transform(dfle.ST_Slope)

dfle.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
# 2   37    1              1        130          283          0           2
# 3   48    0              0        138          214          0           1
# 4   54    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0    172               0      0.0         2             0
# 1    156               0      1.0         1             1
# 2     98               0      0.0         2             0
# 3    108               1      1.5         1             1
# 4    122               0      0.0         2             0

# %%
X = dfle.drop("HeartDisease",axis='columns')
y = dfle.HeartDisease

X.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0   40    1              1        140          289          0           1
# 1   49    0              2        160          180          0           1
# 2   37    1              1        130          283          0           2
# 3   48    0              0        138          214          0           1
# 4   54    1              2        150          195          0           1
#
#    MaxHR  ExerciseAngina  Oldpeak  ST_Slope
# 0    172               0      0.0         2
# 1    156               0      1.0         1
# 2     98               0      0.0         2
# 3    108               1      1.5         1
# 4    122               0      0.0         2

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled
# Out:
# array([[-1.42815446,  0.515943  ,  0.2245723 , ..., -0.8229452 ,
#         -0.85546862,  1.04249607],
#        [-0.47585532, -1.93819859,  1.27063705, ..., -0.8229452 ,
#          0.13751561, -0.62216462],
#        [-1.7455875 ,  0.515943  ,  0.2245723 , ..., -0.8229452 ,
#         -0.85546862,  1.04249607],
#        ...,
#        [ 0.3706328 ,  0.515943  , -0.82149245, ...,  1.21514774,
#          0.33611246, -0.62216462],
#        [ 0.3706328 , -1.93819859,  0.2245723 , ..., -0.8229452 ,
#         -0.85546862, -0.62216462],
#        [-1.63977649,  0.515943  ,  1.27063705, ..., -0.8229452 ,
#         -0.85546862,  1.04249607]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (719, 11)
# (180, 11)

# %%
from sklearn.svm import SVC
model = SVC()

# %%
model.fit(X_train, y_train)
# Out:
# SVC()

# %%
model.score(X_test, y_test)
# Out:
# 0.8666666666666667

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score

bag_model = BaggingClassifier(
    estimator=SVC(), 
    n_estimators=100, 
    max_samples=0.8, 
    oob_score=True,
    random_state=0
)

bag_model.fit(X_train, y_train)
bag_model.score(X_test, y_test)
# Out:
# 0.8666666666666667

# %%
from sklearn.tree import DecisionTreeClassifier
model_2 = DecisionTreeClassifier()

# %%
model_2.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model_2.score(X_test, y_test)
# Out:
# 0.7833333333333333

# %%
bag_model_2 = BaggingClassifier(
    estimator=DecisionTreeClassifier(), 
    n_estimators=100, 
    max_samples=0.8, 
    oob_score=True,
    random_state=0
)
bag_model_2.fit(X_train, y_train)
bag_model_2.score(X_test, y_test)
# Out:
# 0.8833333333333333

# %% [markdown]
# The best perforance was the Decision Tree Classifier using bagging, followed closely by the SVC model (both ways).
#
# Bagging made a much larger difference with Decision Tree Classifier rather than SVC where it had little impact.
#
# Based on my research, Bagging is most beneficial when used with models that have high variance and are thus prone to overfitting.
#
# These include:
#
# Decision Trees, k-Nearest Neighbors (k-NN), Neural Networks, Naive Bayes Classifiers, and more.
#
# I think the justification for Bagging having a lower impact with SVM is that when a SVM is trained to have proper boundaries and doesn't have too many boundaries, it's usually safer from overfitting.

# %%
# try Random Forest

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

scores = cross_val_score(RandomForestClassifier(), X_train, y_train, cv=5)
scores.mean()
# Out:
# 0.8595376845376844
